# %% [markdown]
# # INTRODUCTION
#
# - hvad opgaven går ud på
# - hvad de skal gøre
# - hvad de ikke skal bekymre sig om

# %% [markdown]
# # Exercise 1: Parsons Problem
#
# - Problemtekst

# %%
print("Hello, World!")
# THIS IS A CODE BLOCK
