# %%
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# ## INTRODUCTION

# %% [markdown]
# ## Exercise 1: Parsons Problem
#
# - Arrange the lines of code so the program executes correctly!

# %% [markdown]
# ### Example:
#
# A: `print("This is )`
# B: `print("exercise!")`
# C: `print("the first ")`
#
# #### Solution
# Line 1: A
# Line 2: C
# Line 3: B

# %%
slider = widgets.IntSlider(value=5, min=0, max=10, step=1, description="Test:")
display(slider)
# Out:
# IntSlider(value=5, description='Test:', max=10)

# %%
def f(x):
    return x
widgets.interact(f, x='Hi there!')
# Out:
# interactive(children=(Text(value='Hi there!', description='x'), Output()), _dom_classes=('widget-interact',))
# <function __main__.f(x)>
